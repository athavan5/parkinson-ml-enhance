# %%
import pandas as pd
df_1 = pd.read_excel('Demographics_age_sex_bme_499.xlsx', index_col=0)

# %%
df_1
# Out:
#                                              Label   Age Sex
# Sample ID
# AH_064F_7AB034C9-72E4-438B-A9B3-AD7FDA1596C5    HC  69.0   M
# AH_114S_A89F3548-0B61-4770-B800-2E26AB3908B6    HC  43.0   M
# AH_121A_BD5BA248-E807-4CB9-8B53-47E7FFE5F8E2    HC  18.0   F
# AH_123G_559F0706-2238-447C-BA39-DB5933BA619D    HC  28.0   M
# AH_195B_39DA6A45-F4CC-492A-80D4-FB79049ACC22    HC  68.0   M
# ...                                            ...   ...  ..
# AH_803T_66094C40-AE64-4AD3-AA97-B052C69DA3EF    HC  23.0   F
# AH_821C_8F9D5EF0-18B2-4967-B36D-82E014792BC3    HC  35.0   F
# AH_888A_7F1444B0-B12C-4B55-AF2A-463395DCAF3C    HC  61.0   M
# AH_904H_85B22FC1-BA09-4A17-A374-B00B2445CD27    HC  36.0   F
# AH_942A_3F7867F3-1AE2-4BE6-B5EC-AC3157D310CF    HC  79.0   M
#
# [81 rows x 3 columns]

# %%
df_1['Label'].value_counts()
# Out:
# Label
# HC      41
# PwPD    40
# Name: count, dtype: int64

# %%
df_2 = pd.read_csv('dataset_2.csv', index_col=0)

# %%
df_2
# Out:
#         subject group vowel    jitter   shimmer     HNR       SHR
# record
# HC1a1       HC1    HC     a  0.332226  3.225000  22.942  0.000000
# HC1a2       HC1    HC     a  0.344828  2.730000  23.677  0.000000
# HC1i1       HC1    HC     i  0.432900  1.567000  20.838  0.000000
# HC1i2       HC1    HC     i  0.383142  1.759999  22.681  0.000000
# HC2a1       HC2    HC     a  0.412371  3.732000  20.715  0.000000
# ...         ...   ...   ...       ...       ...     ...       ...
# PSP17i2   PSP17   PSP     i  0.304878  6.124999  22.151  0.000000
# PSP18a1   PSP18   PSP     a  0.431034  5.733000  19.825  0.000000
# PSP18a2   PSP18   PSP     a  0.408163  5.597001  21.245  0.000000
# PSP18i1   PSP18   PSP     i  0.502513  7.457001  22.465  0.000000
# PSP18i2   PSP18   PSP     i  0.480769  3.162000  28.655  0.207593
#
# [337 rows x 7 columns]

# %%
df_2['group'].value_counts()
# Out:
# group
# PD     93
# HC     88
# MSA    84
# PSP    72
# Name: count, dtype: int64
